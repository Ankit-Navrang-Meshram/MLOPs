# %%
text_post = {
    1 : {"title" : "First Post" , "content" : "This is the content of first post"},
    2 : {"title" : "Second Post" , "content" : "This is the content of second post"},
    3 : {"title" : "Third Post" , "content" : "This is the content of third post"} ,
    4 : {"title" : "Fourth Post" , "content" : "This is the content of fourth post"},
    5 : {"title" : "Fifth Post" , "content" : "This is the content of fifth post"},
    6 : {"title" : "Sixth Post" , "content" : "This is the content of sixth post"},
    7 : {"title" : "Seventh Post" , "content" : "This is the content of seventh post"},
    8 : {"title" : "Eighth Post" , "content" : "This is the content of eighth post"},
    9 : {"title" : "Ninth Post" , "content" : "This is the content of ninth post"},
    10 : {"title" : "Tenth Post" , "content" : "This is the content of tenth post"},
}

# %%
from pydantic import BaseModel

class Post(BaseModel):
    title : str
    content : str


post1 = Post(**text_post[1])

# %%
# i have to create a list of pydantic post 

l = list(Post(**text_post[i]) for i in range(1 , 5))

# %%
l = text_post.values()

# %%
l = [Post(**k) for k in l]

# %%
l
# Out:
# [Post(title='First Post', content='This is the content of first post'),
#  Post(title='Second Post', content='This is the content of second post'),
#  Post(title='Third Post', content='This is the content of third post'),
#  Post(title='Fourth Post', content='This is the content of fourth post'),
#  Post(title='Fifth Post', content='This is the content of fifth post'),
#  Post(title='Sixth Post', content='This is the content of sixth post'),
#  Post(title='Seventh Post', content='This is the content of seventh post'),
#  Post(title='Eighth Post', content='This is the content of eighth post'),
#  Post(title='Ninth Post', content='This is the content of ninth post'),
#  Post(title='Tenth Post', content='This is the content of tenth post')]

# %%
import os 

file_path = "home/ankit/mlops/rough.txt"

file_name = os.path.splitext(file_path)[1]

# %%
file_name
# Out:
# '.txt'
